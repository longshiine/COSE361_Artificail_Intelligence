# %% [markdown]
# # 2021 인공지능 실습 3차시 - 기계학습 1
# 학번 & 이름: 2017320123 김장영

# %% [markdown]
# 실습 공지사항:
# - 실습 과제 제출 기한: 6월 3일 오후 1시 59분
# - 실습 4차시: 6월 10일
# - 기말 프로젝트 공지: 6월 4일
# - 기말 프로젝트 기한: 6월 18일
# - 6월 17일 수업 없음
#
# 실습 도구:
# - Orange3
# - scikit-learn

# %% [markdown]
# ## 1. Import data and its stats
# Documentation: https://scikit-learn.org/stable/index.html
#
# UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/index.php
#
# `["gender", "length", "diameter", "height", "whole_weight", "shucked_weight", "viscera_weight", "shell_weight", "rings"]`

# %%
# import statements
import numpy as np

# %%
# import data
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data"

# %%
# view data

# %%
# set column names

# %%
# view data types

# %%
# 데이터 통계

# %%
# counting data

# %% [markdown]
# ## 2. Data visualization

# %%
# plot label

# %%
# histogram 1

# %%
# histogram 2

# %%
# histogram 3

# %%
# kernel density 1

# %%
# kernel density 2

# %%
# pair plot

# %% [markdown]
# ## 3. Data Preprocessing
#
# 참고: https://scikit-learn.org/stable/modules/preprocessing.html#preprocessing

# %% [markdown]
# ### 3-1. Data Cleaning

# %%
# missing value check

# %%
# drop missing value if any

# %% [markdown]
# ### 3-2. Data Encoding
# - Ordinal Encoding: 순서 중요
#   - 예)
#
#     ![image.png](data:image/png;base64,...)
#   - [OrdinalEncoder](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OrdinalEncoder.html#sklearn.preprocessing.OrdinalEncoder) 사용

# %% [markdown]
# - Nominal Encoding: 순서 없음
#   - 예)
#     ![image.png](data:image/png;base64,...)
#   - [OneHotEncoder](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html#sklearn.preprocessing.OneHotEncoder) 혹은 [pd.get_dummies](https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html) 사용
#   - 카테고리가 많을 경우 feature이 늘어나니 주의

# %%
# gender 특성 one-hot encoding

# %%
# 데이터 병합

# %% [markdown]
# ### 3-3. Data discretization for classification

# %%
# plot label distribution

# %%
# discretize label

# %%
# 결과 확인

# %%
# 결과 확인

# %%
# 데이터 병합

# %% [markdown]
# ## 4. Split Data
#
# documentation: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# split data to X and y

# %%
# 확인

# %%
# split train, validation and test data

# %%
# check dimension

# %% [markdown]
# ## 5. Build and Train Model
#
# Decision Tree: https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

# %%
# build and train decision tree

# %%
# get validation accuracy

# %%
# plot feature importance
def plot_imp(clf, data):
  sorted_idx = clf.feature_importances_.argsort()
  y_ticks = np.arange(0, len(data.columns))
  fig, ax = plt.subplots()
  ax.barh(y_ticks, clf.feature_importances_[sorted_idx])
  ax.set_yticklabels(data.columns[sorted_idx])
  ax.set_yticks(y_ticks)
  fig.tight_layout()
  plt.show()

# %%
# 트리 시각화
from sklearn.tree import export_graphviz # drawing graphs specified in DOT language scripts
from sklearn.externals.six import StringIO
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(decTree, feature_names=X_train.columns, out_file=dot_data)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('/tree.png')
Image(graph.create_png())

# %% [markdown]
# ## 6. Pruning
#
# Decision Tree: https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

# %%
# build pruned decision tree

# %%
# check accuracy

# %%
# plot pruned tree

# %% [markdown]
# ## 7. Model Evaluation
#
# ### 7-1. Confusion Matrix
#
#   - confusion_matrix: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html#sklearn.metrics.confusion_matrix
#   - plot_confusion_matrix: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.plot_confusion_matrix.html#sklearn.metrics.plot_confusion_matrix

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# plot confusion matrix - not normalized

# %%
# plot confusion matrix - normalized

# %% [markdown]
# ### 7-2. Classification report
# documentation: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html

# %%
# print classification report

# %% [markdown]
# ### 7-3. AUROC score
#
# roc_auc_score: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# print auroc score

# %% [markdown]
# ### 7-4. Compare Validation accuracy

# %%
# print accuracy

# %%
# print auroc score

# %% [markdown]
# ### 7-5. Final evaluation on test dataset

# %%
# print classification report

# %%
# print auroc score

# %% [markdown]
# # 실습 과제
#
# Scikit-learn Decision Tree Documentation: https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
#
# * 과제 1: 위 제공된 링크의 `DecisionTreeClassifier` 다큐멘테이션을 읽고 `max_leaf_nodes`, `max_depth`, `min_sample_split`, `min_sample_leaf` 각각의 파라미터가 pruning에 있어서 어떤 역할을 하는지 설명하시오. (4점)
# * 과제 2: 총 4개의 새로운 결정트리 모델을 생성하여 train 데이터에 훈련시켜봅시다. 이 때 각각의 결정트리 모델은 `max_leaf_nodes`, `max_depth`, `min_sample_split`, `min_sample_leaf`의 네개의 pruning 파라미터 중 하나씩을 임의로 조정해주어야 합니다.(하나의 결정 트리는 하나의 pruning 파라미터만 조정하면 되고, 각각의 결정트리는 서로 다른 파라미터를 조정해야합니다.) (4점)
# * 과제 3: pruning 파라미터를 조정한 4개의 결정트리에 대해 validation dataset에 대한 분류 정확도(classification report, auroc score)를 확인해보고, pruning 파라미터를 조정하지 않았던 결정트리의 분류 정확도와 비교하여 그 차이를 서술합니다. (6점)
# * 과제 4: 생성된 4개의 결정트리 모델 각각을 시각화해봅시다. (4점)
# * 과제 5: validation 데이터을 통해 가장 좋은 모델을 선정하고, test 데이터에 그 모델의 성능(classification report, auroc score)을 평가하여 최종 모델 성능을 서술합니다. (3점)
